# %% [markdown]
# <a href="https://colab.research.google.com/github/Dzakiyy-ah/Spring-Club-Explorer/blob/main/FinalProject_SpringClubExplorer.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

df = pd.read_csv('/content/drive/MyDrive/Spring Club Explorer/FinalProject/four_seasons_ta_1000_reviews.csv')

# %%
df.head(3)
# Out:
#   publishedDate                                              title  \
# 0    2024-01-23            Professional stuff and kind people but…
# 1    2024-01-22                     Better than our expectations.
# 2    2024-01-21  SPECTACULAR HOTEL, INCREDIBLE TEAM,  DECOR and...
#
#                                                 text  \
# 0  The only problem we had in Paris was the water...
# 1  We had the pleasure of staying at an elegant h...
# 2  SPECTACULAR HOTEL, INCREDIBLE TEAM,  DECOR and...
#
#   ownerResponse/publishedDate ownerResponse/responder  \
# 0                  2024-01-24            Four Seasons
# 1                  2024-01-23            Four Seasons
# 2                  2024-01-21            Four Seasons
#
#                                        ownerResponse  rating
# 0  Dear elenahueanu,  \n\nThank you for the const...       4
# 1  Dear Elly,  \n\nA warm thank you on behalf of ...       5
# 2  Dear Alla,  \n\nThank you very much for choosi...       5

# %%
df.tail(3)
# Out:
#     publishedDate                                     title  \
# 997    2017-04-22    The most civilized hotel in the world
# 998    2017-04-22                        honeymoon in Paris
# 999    2017-04-19  Un palace qui garde toutes ses promesses
#
#                                                   text  \
# 997  They greeted us at the curb, all smiles and ha...
# 998  The staff at the George V is professional beyo...
# 999  Service toujours au top, merci à Rachid qui no...
#
#     ownerResponse/publishedDate ownerResponse/responder ownerResponse  rating
# 997                         NaN                     NaN           NaN       5
# 998                         NaN                     NaN           NaN       5
# 999                         NaN                     NaN           NaN       5

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 7 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   publishedDate                1000 non-null   object
#  1   title                        1000 non-null   object
#  2   text                         1000 non-null   object
#  3   ownerResponse/publishedDate  489 non-null    object
#  4   ownerResponse/responder      489 non-null    object
#  5   ownerResponse                489 non-null    object
#  6   rating                       1000 non-null   int64
# dtypes: int64(1), object(6)
# memory usage: 54.8+ KB
